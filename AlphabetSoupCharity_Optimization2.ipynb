# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

#  Import and read the charity_data.csv.
import pandas as pd 
app_df = pd.read_csv('Resources/charity_data.csv')
app_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df=app_df.drop(['EIN', 'NAME'], axis= 1)
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts(ascending = True)
# Out:
# T17        1
# T15        2
# T29        2
# T14        3
# T25        3
# T2        16
# T12       27
# T13       66
# T9       156
# T10      528
# T7       725
# T8       737
# T19     1065
# T5      1173
# T6      1216
# T4      1542
# T3     27037
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = application_types_to_replace.loc[application_types_to_replace<500].index.values #300 to 400

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
df['CLASSIFICATION'].value_counts()>1
# Out:
# C1000     True
# C2000     True
# C1200     True
# C3000     True
# C2100     True
#          ...
# C4120    False
# C8210    False
# C2561    False
# C4500    False
# C2150    False
# Name: CLASSIFICATION, Length: 71, dtype: bool

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classification_to_replace=df['CLASSIFICATION'].value_counts()
classification_to_replace=classification_to_replace.loc[classification_to_replace<1500].index.values #to 1400

# Replace in dataframe
for cls in classification_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df2=pd.get_dummies(df)
df2
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = df2.IS_SUCCESSFUL.values
X = df2.drop(columns =['IS_SUCCESSFUL']).values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  75
hidden_nodes_layer2 = 50 #=change to 100 and 75



nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 75)                3300
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                3800
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 7,151
# Trainable params: 7,151
# Non-trainable params: 0
# _________________________________________________________________
# 2021-11-30 23:30:03.304914: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-30 23:30:03.305410: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=50) #change epochs to 25
# Out:
# Train on 25724 samples
# Epoch 1/50
# 25724/25724 [==============================] - 3s 111us/sample - loss: 0.5763 - accuracy: 0.7157
# Epoch 2/50
# 25724/25724 [==============================] - 2s 84us/sample - loss: 0.5554 - accuracy: 0.7292
# Epoch 3/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5533 - accuracy: 0.7292
# Epoch 4/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5505 - accuracy: 0.7302
# Epoch 5/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5505 - accuracy: 0.7303
# Epoch 6/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5491 - accuracy: 0.7315
# Epoch 7/50
# 25724/25724 [==============================] - 2s 88us/sample - loss: 0.5490 - accuracy: 0.7308
# Epoch 8/50
# 25724/25724 [==============================] - 2s 88us/sample - loss: 0.5477 - accuracy: 0.7315
# Epoch 9/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5477 - accuracy: 0.7308
# Epoch 10/50
# 25724/25724 [==============================] - 2s 85us/sample - loss: 0.5474 - accuracy: 0.7327
# Epoch 11/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5470 - accuracy: 0.7316
# Epoch 12/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5463 - accuracy: 0.7320
# Epoch 13/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5459 - accuracy: 0.7331
# Epoch 14/50
# 25724/25724 [==============================] - 2s 91us/sample - loss: 0.5456 - accuracy: 0.7329
# Epoch 15/50
# 25724/25724 [==============================] - 2s 88us/sample - loss: 0.5455 - accuracy: 0.7329
# Epoch 16/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5448 - accuracy: 0.7340
# Epoch 17/50
# 25724/25724 [==============================] - 2s 85us/sample - loss: 0.5447 - accuracy: 0.7335
# Epoch 18/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5444 - accuracy: 0.7335
# Epoch 19/50
# 25724/25724 [==============================] - 2s 88us/sample - loss: 0.5444 - accuracy: 0.7345
# Epoch 20/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5438 - accuracy: 0.7350
# Epoch 21/50
# 25724/25724 [==============================] - 2s 90us/sample - loss: 0.5436 - accuracy: 0.7343
# Epoch 22/50
# 25724/25724 [==============================] - 2s 93us/sample - loss: 0.5434 - accuracy: 0.7354
# Epoch 23/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5430 - accuracy: 0.7347
# Epoch 24/50
# 25724/25724 [==============================] - 2s 89us/sample - loss: 0.5429 - accuracy: 0.7361
# Epoch 25/50
# 25724/25724 [==============================] - 2s 88us/sample - loss: 0.5427 - accuracy: 0.7354
# Epoch 26/50
# 25724/25724 [==============================] - 2s 89us/sample - loss: 0.5420 - accuracy: 0.7360
# Epoch 27/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5420 - accuracy: 0.7350
# Epoch 28/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5415 - accuracy: 0.7357
# Epoch 29/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5418 - accuracy: 0.7362
# Epoch 30/50
# 25724/25724 [==============================] - 2s 89us/sample - loss: 0.5414 - accuracy: 0.7356
# Epoch 31/50
# 25724/25724 [==============================] - 2s 93us/sample - loss: 0.5413 - accuracy: 0.7352
# Epoch 32/50
# 25724/25724 [==============================] - 2s 94us/sample - loss: 0.5407 - accuracy: 0.7363
# Epoch 33/50
# 25724/25724 [==============================] - 2s 92us/sample - loss: 0.5404 - accuracy: 0.7357
# Epoch 34/50
# 25724/25724 [==============================] - 2s 86us/sample - loss: 0.5407 - accuracy: 0.7363
# Epoch 35/50
# 25724/25724 [==============================] - 2s 83us/sample - loss: 0.5398 - accuracy: 0.7369
# Epoch 36/50
# 25724/25724 [==============================] - 2s 89us/sample - loss: 0.5402 - accuracy: 0.7360
# Epoch 37/50
# 25724/25724 [==============================] - 2s 95us/sample - loss: 0.5398 - accuracy: 0.7363
# Epoch 38/50
# 25724/25724 [==============================] - 3s 98us/sample - loss: 0.5395 - accuracy: 0.7355
# Epoch 39/50
# 25724/25724 [==============================] - 2s 87us/sample - loss: 0.5393 - accuracy: 0.7359
# Epoch 40/50
# 25724/25724 [==============================] - 2s 84us/sample - loss: 0.5392 - accuracy: 0.7366
# Epoch 41/50
# 25724/25724 [==============================] - 2s 90us/sample - loss: 0.5388 - accuracy: 0.7373
# Epoch 42/50
# 25724/25724 [==============================] - 3s 102us/sample - loss: 0.5389 - accuracy: 0.7373
# Epoch 43/50
# 25724/25724 [==============================] - 12s 465us/sample - loss: 0.5386 - accuracy: 0.7372
# Epoch 44/50
# 25724/25724 [==============================] - 22s 837us/sample - loss: 0.5386 - accuracy: 0.7376
# Epoch 45/50
# 25724/25724 [==============================] - 2s 90us/sample - loss: 0.5384 - accuracy: 0.7377
# Epoch 46/50
# 25724/25724 [==============================] - 9s 333us/sample - loss: 0.5383 - accuracy: 0.7375
# Epoch 47/50
# 25724/25724 [==============================] - 19s 752us/sample - loss: 0.5381 - accuracy: 0.7386
# Epoch 48/50
# 25724/25724 [==============================] - 16s 608us/sample - loss: 0.5378 - accuracy: 0.7378
# Epoch 49/50
# 25724/25724 [==============================] - 19s 725us/sample - loss: 0.5378 - accuracy: 0.7385
# Epoch 50/50
# 25724/25724 [==============================] - 23s 891us/sample - loss: 0.5370 - accuracy: 0.7371

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/1 - 1s - loss: 0.5454 - accuracy: 0.7301
# Loss: 0.5558209985963805, Accuracy: 0.7301457524299622

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization2.h5")
